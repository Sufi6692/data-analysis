# %%
# Dataset : https://drive.google.com/file/d/1iSdnql_06zY32iFfdmUzFwOL47p0CTbR/view?usp=sharing
# Problem statement :https://drive.google.com/file/d/1VajldMkFs5b6W3gsw1mNjKTyCxylpQDs/view?usp=sharing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("US_honey_dataset.csv")
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
#        stocks  average_price  value_of_production  year
# 0       28000          62.00               575000  1995
# 1      986000          68.00              2793000  1995
# 2      900000          64.00              1920000  1995
# 3     4687000          60.00             23436000  1995
# 4     1404000          68.00              1836000  1995
# ...       ...            ...                  ...   ...
# 1110    79000           8.23              1975000  2021
# 1111  1206000           2.52              7741000  2021
# 1112   136000           4.80              1238000  2021
# 1113   750000           2.81              5547000  2021
# 1114   242000           2.07              4562000  2021
#
# [1115 rows x 9 columns]

# %%
# Remove the extra Unnamed: 0 column
df = df.drop(["Unnamed: 0"], axis=1)
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# 0             62.00               575000  1995
# 1             68.00              2793000  1995
# 2             64.00              1920000  1995
# 3             60.00             23436000  1995
# 4             68.00              1836000  1995
# ...             ...                  ...   ...
# 1110           8.23              1975000  2021
# 1111           2.52              7741000  2021
# 1112           4.80              1238000  2021
# 1113           2.81              5547000  2021
# 1114           2.07              4562000  2021
#
# [1115 rows x 8 columns]

# %%
df.head(50)
# Out:
#             state  colonies_number  yield_per_colony  production   stocks  \
# 0         Alabama            16000                58      928000    28000
# 1         Arizona            52000                79     4108000   986000
# 2        Arkansas            50000                60     3000000   900000
# 3      California           420000                93    39060000  4687000
# 4        Colorado            45000                60     2700000  1404000
# 5         Florida           230000                86    19780000  1780000
# 6         Georgia            70000                62     4340000   260000
# 7          Hawaii             8000               129     1032000   103000
# 8           Idaho           125000                48     6000000  1020000
# 9        Illinois            11000                74      814000   212000
# 10        Indiana            12000                63      756000   166000
# 11           Iowa            50000                68     3400000   612000
# 12         Kansas            17000                67     1139000   182000
# 13       Kentucky             3000                44      132000    30000
# 14      Louisiana            33000               119     3927000   275000
# 15          Maine            11000                45      495000   223000
# 16       Maryland             7000                35      245000    81000
# 17       Michigan            97000                92     8924000  3570000
# 18      Minnesota           165000                82    13530000  1218000
# 19    Mississippi            16000                70     1120000   146000
# 20       Missouri            23000                67     1541000   308000
# 21        Montana           106000                80     8480000  1781000
# 22       Nebraska            60000                73     4380000  1402000
# 23         Nevada             9000                29      261000    34000
# 24      NewJersey             8000                34      272000    57000
# 25      NewMexico            19000                65     1235000   247000
# 26        NewYork            70000                75     5250000  2100000
# 27  NorthCarolina            12000                52      624000   162000
# 28    NorthDakota           220000               108    23760000  3802000
# 29           Ohio            25000                62     1550000   930000
# 30       Oklahoma             5000                76      380000   141000
# 31         Oregon            52000                52     2704000  2488000
# 32   Pennsylvania            25000                43     1075000   376000
# 33  SouthCarolina             9000                90      810000    65000
# 34    SouthDakota           240000                85    20400000  4896000
# 35      Tennessee             4000                53      212000    70000
# 36          Texas            84000               106     8904000  1959000
# 37           Utah            32000                33     1056000   232000
# 38        Vermont             5000                67      335000   131000
# 39       Virginia             9000                45      405000    97000
# 40     Washington            60000                59     3540000   637000
# 41   WestVirginia            13000                41      533000    48000
# 42      Wisconsin            73000                79     5767000  2134000
# 43        Wyoming            38000                36     1368000   150000
# 44        Alabama            16000                64     1024000   102000
# 45        Arizona            32000                60     1920000   307000
# 46       Arkansas            40000                84     3360000   336000
# 47     California           390000                70    27300000  4641000
# 48       Colorado            30000                74     2220000  1132000
# 49        Florida           240000               105    25200000  2268000
#
#     average_price  value_of_production  year
# 0            62.0               575000  1995
# 1            68.0              2793000  1995
# 2            64.0              1920000  1995
# 3            60.0             23436000  1995
# 4            68.0              1836000  1995
# 5            63.0             12461000  1995
# 6            69.0              2995000  1995
# 7            55.0               568000  1995
# 8            65.0              3900000  1995
# 9           102.0               830000  1995
# 10           68.0               514000  1995
# 11           72.0              2448000  1995
# 12           71.0               809000  1995
# 13          103.0               136000  1995
# 14           61.0              2395000  1995
# 15          100.0               495000  1995
# 16          114.0               279000  1995
# 17           72.0              6425000  1995
# 18           66.0              8930000  1995
# 19           64.0               717000  1995
# 20           65.0              1002000  1995
# 21           66.0              5597000  1995
# 22           68.0              2978000  1995
# 23           96.0               251000  1995
# 24           71.0               193000  1995
# 25           68.0               840000  1995
# 26           66.0              3465000  1995
# 27           81.0               505000  1995
# 28           63.0             14969000  1995
# 29           72.0              1116000  1995
# 30           91.0               346000  1995
# 31           71.0              1920000  1995
# 32           69.0               742000  1995
# 33          128.0              1037000  1995
# 34           65.0             13260000  1995
# 35          114.0               242000  1995
# 36           64.0              5699000  1995
# 37           61.0               644000  1995
# 38           83.0               278000  1995
# 39           55.0               223000  1995
# 40           54.0              1912000  1995
# 41          116.0               618000  1995
# 42           71.0              4095000  1995
# 43           68.0               930000  1995
# 44           86.0               881000  1996
# 45           84.0              1613000  1996
# 46           87.0              2923000  1996
# 47           84.0             22932000  1996
# 48           79.0              1754000  1996
# 49           91.0             22932000  1996

# %% [markdown]
# # EDA - Exploratory Data Analysis
#
# Explore your data before performing any analysis so if some issue are there in your data , resolve it

# %%
# Check for missing values in your data
df.isnull().sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.isna().sum()  #.sum() to get the final count of null values inour data rather than manually calcualting wr will use .sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
# Check for duplicate data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check the data type of columns
df.info()  # It will provide a summary stats report
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                1115 non-null   object
#  1   colonies_number      1115 non-null   int64
#  2   yield_per_colony     1115 non-null   int64
#  3   production           1115 non-null   int64
#  4   stocks               1115 non-null   int64
#  5   average_price        1115 non-null   float64
#  6   value_of_production  1115 non-null   int64
#  7   year                 1115 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 69.8+ KB

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Which states are rarely contributing to honey production for the last 27 years?
#
# In simple word find out that which state have produced honey for how many years from 1995 to 2021 and then check which state have produced honey for the least no of years

# %%
# Hint - Count which state name is being repeated how many times in our data
# So we have data of 27 years from 1995 to 2021 so just count how many times each state name is being repeated in our data
df["state"].value_counts()
# Out:
# state
# Alabama          27
# Arizona          27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Mississippi      27
# Minnesota        27
# Montana          27
# Missouri         27
# NorthCarolina    27
# NewYork          27
# Nebraska         27
# NewJersey        27
# Pennsylvania     27
# Oregon           27
# Ohio             27
# NorthDakota      27
# Washington       27
# WestVirginia     27
# Vermont          27
# Virginia         27
# Tennessee        27
# SouthDakota      27
# Utah             27
# Texas            27
# Wisconsin        27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Maryland          9
# Oklahoma          9
# Name: count, dtype: int64

# %% [markdown]
# # Conclusion
#
# SouthCarolina	= 12
#
# Maryland	= 9
#
# Oklahoma	 = 9
#
# Least times Honey producing states in US from 1995 to 2021

# %% [markdown]
# # Which are the top 5 Honey producing states in the US ?
#
# You need to find from 1995 to 2021 which state have produced the highest amount of honey by using "production" column

# %%
ans = df.groupby("state").sum()
ans
# Out:
#                colonies_number  yield_per_colony  production     stocks  \
# state
# Alabama                 288000              1615    14467000    2987000
# Arizona                 854000              1490    38844000   17758000
# Arkansas                908000              1886    51846000   20897000
# California            10135000              1426   423876000  137611000
# Colorado                799000              1520    32660000   18695000
# Florida                5528000              1956   280934000   47037000
# Georgia                1917000              1354    57426000    9932000
# Hawaii                  296000              2802    15420000    3508000
# Idaho                  2705000              1121    87188000   40503000
# Illinois                236000              1562     9864000    4957000
# Indiana                 213000              1605     9686000    5286000
# Iowa                    962000              1659    48607000   29351000
# Kansas                  301000              1570    14138000    7520000
# Kentucky                113000              1260     3224000    1128000
# Louisiana              1066000              2506    60568000   12688000
# Maine                   252000               888     4762000    2271000
# Maryland                 48000               377     1975000     477000
# Michigan               2168000              1753   101063000   58401000
# Minnesota              3498000              1885   176581000   51908000
# Mississippi             485000              2341    21235000    6799000
# Missouri                390000              1460    17904000    4870000
# Montana                3725000              2148   197173000   91240000
# Nebraska               1279000              1729    63655000   38937000
# Nevada                  157000               700     7399000    1935000
# NewJersey               299000               958     6913000    3311000
# NewMexico               185000              1010    10082000    4561000
# NewYork                1588000              1745    78444000   42535000
# NorthCarolina           304000              1236     8909000    3101000
# NorthDakota           10710000              2266   513742000  206707000
# Ohio                    449000              1763    22485000   13269000
# Oklahoma                 40000               471     2055000     693000
# Oregon                 1594000              1145    43789000   28655000
# Pennsylvania            586000              1317    21370000   11339000
# SouthCarolina           148000               727     2823000     486000
# SouthDakota            6639000              1950   355726000  218634000
# Tennessee               189000              1497     6857000    2460000
# Texas                  2876000              1921   129441000   41022000
# Utah                    719000              1130    20369000    6775000
# Vermont                 149000              1674     7032000    3489000
# Virginia                170000              1097     5153000    1809000
# Washington             1709000              1255    53238000   28500000
# WestVirginia            179000              1245     6411000    3034000
# Wisconsin              1698000              1896    99909000   59166000
# Wyoming                1065000              1698    43921000   11235000
#
#                average_price  value_of_production   year
# state
# Alabama              4057.61             28668000  54216
# Arizona              2978.77             59772000  54216
# Arkansas             2870.45             73781000  54216
# California           2954.06            653982000  54216
# Colorado             3200.56             63844000  54216
# Florida              2967.52            509670000  54216
# Georgia              3260.68            145945000  54216
# Hawaii               3719.13             49888000  54216
# Idaho                2869.71            139536000  54216
# Illinois             5842.43             36782000  54216
# Indiana              4183.16             24658000  54216
# Iowa                 3341.75             87563000  54216
# Kansas               3977.44             27970000  54216
# Kentucky             5250.45             15427000  52212
# Louisiana            2783.02            129601000  54216
# Maine                4691.80             19842000  54216
# Maryland             1310.00              2735000  17991
# Michigan             3311.97            217841000  54216
# Minnesota            2887.89            310462000  54216
# Mississippi          2776.70             59265000  54216
# Missouri             3941.76             32372000  54216
# Montana              2961.17            406563000  54216
# Nebraska             3004.31            106998000  54216
# Nevada               3068.00             14520000  30030
# NewJersey            5262.74             28201000  54216
# NewMexico            2197.00             11049000  36063
# NewYork              3663.52            177921000  54216
# NorthCarolina        5540.21             38645000  54216
# NorthDakota          2863.08           1186219000  54216
# Ohio                 4417.38             59637000  54216
# Oklahoma             1203.00              2618000  17991
# Oregon               3221.40            102109000  54216
# Pennsylvania         4130.82             55153000  54216
# SouthCarolina        2111.96             26218000  24136
# SouthDakota          2891.51            619095000  54216
# Tennessee            5318.06             27276000  54216
# Texas                2965.74            284720000  54216
# Utah                 3003.27             40157000  54216
# Vermont              4689.46             19084000  54216
# Virginia             6419.69             20925000  54216
# Washington           3208.36            119823000  54216
# WestVirginia         5162.20             18685000  54216
# Wisconsin            3410.87            176442000  54216
# Wyoming              2904.12             87502000  54216

# %%
ans = df.groupby("state").sum().sort_values("production", ascending=False).reset_index()

'''
df.groupby("state").sum()   - It will group the data of each state by addding its total values
.sort_values("production", ascending=False)  - After grouping it will arrange the data in descending order of total production
.reset_index()    - After grouping the index will be disturbed so it will fix the index

'''

ans[["state", "production"]]
# Out:
#             state  production
# 0     NorthDakota   513742000
# 1      California   423876000
# 2     SouthDakota   355726000
# 3         Florida   280934000
# 4         Montana   197173000
# 5       Minnesota   176581000
# 6           Texas   129441000
# 7        Michigan   101063000
# 8       Wisconsin    99909000
# 9           Idaho    87188000
# 10        NewYork    78444000
# 11       Nebraska    63655000
# 12      Louisiana    60568000
# 13        Georgia    57426000
# 14     Washington    53238000
# 15       Arkansas    51846000
# 16           Iowa    48607000
# 17        Wyoming    43921000
# 18         Oregon    43789000
# 19        Arizona    38844000
# 20       Colorado    32660000
# 21           Ohio    22485000
# 22   Pennsylvania    21370000
# 23    Mississippi    21235000
# 24           Utah    20369000
# 25       Missouri    17904000
# 26         Hawaii    15420000
# 27        Alabama    14467000
# 28         Kansas    14138000
# 29      NewMexico    10082000
# 30       Illinois     9864000
# 31        Indiana     9686000
# 32  NorthCarolina     8909000
# 33         Nevada     7399000
# 34        Vermont     7032000
# 35      NewJersey     6913000
# 36      Tennessee     6857000
# 37   WestVirginia     6411000
# 38       Virginia     5153000
# 39          Maine     4762000
# 40       Kentucky     3224000
# 41  SouthCarolina     2823000
# 42       Oklahoma     2055000
# 43       Maryland     1975000

# %%
# Increase the size of plot
plt.figure(figsize=(20,10))

sns.barplot(x=ans["state"] ,  y=ans["production"])

# To rotate the name of state by 90 degree to avoid overlapping
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Conclusion
#
# NorthDakota	,C alifornia ,SouthDakota	, Florida	, Montana	 are the top 5 honey producing states

# %% [markdown]
# # What is the Change in mean Average price of Honey from 1995 to 2021?
#
# Hint - Find the average price of honey of all states in 1995 then for 2021 and then see the difference

# %%
new_df = df.groupby("year").mean("average_price").reset_index()
new_df[["year","average_price"]]
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
new_df [(new_df["year"]==1995 ) | (new_df["year"]==2021)]   # | means or
# Out:
#     year  colonies_number  yield_per_colony    production    stocks  \
# 0   1995     59977.272727         66.909091  4.778909e+06  957500.0
# 26  2021     66700.000000         46.700000  5.796750e+05  579675.0
#
#     average_price  value_of_production
# 0       74.840909            3121000.0
# 26       3.334250            7860325.0

# %% [markdown]
# # Conclusion
#
# Year     Average Price
#
# 1995	 , 74.840909
#
# 2021	,  3.334250

# %% [markdown]
# # Which was the year when production of Honey in wholeUS was the highest?

# %%
df5= df.groupby('year').sum().sort_values("production",ascending=False).reset_index()
df5[["year","production"]]
# Out:
#     year  production
# 0   2000   220320000
# 1   1998   219321000
# 2   1995   210272000
# 3   1999   204585000
# 4   1996   197995000
# 5   1997   191176000
# 6   2001   185403000
# 7   2004   182379000
# 8   2003   180741000
# 9   2005   173857000
# 10  2002   170732000
# 11  2008   160096000
# 12  2006   154120000
# 13  2007   147609000
# 14  2009   143340000
# 15  2010    44797000
# 16  2015    41832000
# 17  2014    40990000
# 18  2016    40837000
# 19  2019    40510000
# 20  2020    39412000
# 21  2013    37974000
# 22  2011    36550000
# 23  2012    31662000
# 24  2017    30478000
# 25  2018    28989000
# 26  2021    23187000

# %% [markdown]
# # Conclusion
#
# In year 2000 the honey production was highest in US with - 220320000

# %% [markdown]
# # From the above inference we get the production was highest in the year 2000, now let infer which state was having highest contribution in that year
#
# in simple words - we know that in year 2000 production was highest , now please find which state was having the highest contribution in the proudction in 2000

# %%
# Fetch data where year==2000 then find our which state is having highest production
# data = df[(df["year"]==2000 )]

data = df[ (df["year"]==2000 ) ]
ans = data.sort_values("production", ascending=False)
ans
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 245    NorthDakota           290000               115    33350000  13340000
# 220     California           440000                70    30800000  11396000
# 250    SouthDakota           235000               121    28435000  12796000
# 222        Florida           232000               105    24360000   2923000
# 235      Minnesota           150000                90    13500000   3105000
# 238        Montana           148000                86    12728000   5982000
# 252          Texas           105000                79     8295000   2986000
# 258      Wisconsin            84000                90     7560000   4385000
# 234       Michigan            72000                75     5400000   2970000
# 219       Arkansas            55000                93     5115000   3529000
# 225          Idaho           100000                47     4700000   2679000
# 243        NewYork            58000                80     4640000   2274000
# 239       Nebraska            50000                87     4350000   2610000
# 231      Louisiana            43000                94     4042000   1334000
# 259        Wyoming            39000                93     3627000    798000
# 223        Georgia            55000                57     3135000    376000
# 256     Washington            52000                54     2808000   1151000
# 248         Oregon            48000                51     2448000   1665000
# 218        Arizona            40000                59     2360000   1322000
# 228           Iowa            30000                67     2010000   1206000
# 221       Colorado            29000                60     1740000    957000
# 237       Missouri            23000                75     1725000    362000
# 217        Alabama            16000                78     1248000    187000
# 236    Mississippi            17000                72     1224000    649000
# 246           Ohio            18000                65     1170000    585000
# 229         Kansas            15000                68     1020000    520000
# 249   Pennsylvania            22000                45      990000    554000
# 253           Utah            24000                41      984000    462000
# 242      NewMexico            15000                64      960000    739000
# 224         Hawaii             7000               112      784000    125000
# 251      Tennessee             9000                61      549000    104000
# 244  NorthCarolina            11000                49      539000    243000
# 227        Indiana             8000                65      520000    286000
# 226       Illinois             8000                61      488000    146000
# 254        Vermont             7000                59      413000    211000
# 241      NewJersey            11000                35      385000    200000
# 257   WestVirginia             7000                54      378000    234000
# 240         Nevada            10000                35      350000     95000
# 255       Virginia             7000                42      294000    103000
# 233       Maryland             6000                46      276000     52000
# 247       Oklahoma             7000                35      245000     64000
# 232          Maine            11000                21      231000    143000
# 230       Kentucky             3000                48      144000     40000
#
#      average_price  value_of_production  year
# 245           56.0             18676000  2000
# 220           58.0             17864000  2000
# 250           57.0             16208000  2000
# 222           54.0             13154000  2000
# 235           57.0              7695000  2000
# 238           59.0              7510000  2000
# 252           57.0              4728000  2000
# 258           68.0              5141000  2000
# 234           60.0              3240000  2000
# 219           57.0              2916000  2000
# 225           52.0              2444000  2000
# 243           55.0              2552000  2000
# 239           59.0              2567000  2000
# 231           52.0              2102000  2000
# 259           59.0              2140000  2000
# 223           63.0              1975000  2000
# 256           58.0              1629000  2000
# 248           66.0              1616000  2000
# 218           73.0              1723000  2000
# 228           67.0              1347000  2000
# 221           62.0              1079000  2000
# 237           60.0              1035000  2000
# 217           59.0               736000  2000
# 236           69.0               845000  2000
# 246           79.0               924000  2000
# 229           91.0               928000  2000
# 249           76.0               752000  2000
# 253           60.0               590000  2000
# 242           72.0               691000  2000
# 224           81.0               635000  2000
# 251          143.0               785000  2000
# 244          143.0               771000  2000
# 227          103.0               536000  2000
# 226          117.0               571000  2000
# 254           68.0               281000  2000
# 241           61.0               235000  2000
# 257          122.0               461000  2000
# 240          145.0               508000  2000
# 255          150.0               441000  2000
# 233          114.0               315000  2000
# 247          126.0               309000  2000
# 232           75.0               173000  2000
# 230          135.0               194000  2000

# %% [markdown]
# # Conclusion -
#
# NorthDakota is the state having highest production in year 2000

# %% [markdown]
# # Which states have the highest no. of colonies in the year 2000?

# %%
data = df[ (df["year"]==2000 ) ]
ans = data.sort_values("colonies_number", ascending=False)
ans
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 220     California           440000                70    30800000  11396000
# 245    NorthDakota           290000               115    33350000  13340000
# 250    SouthDakota           235000               121    28435000  12796000
# 222        Florida           232000               105    24360000   2923000
# 235      Minnesota           150000                90    13500000   3105000
# 238        Montana           148000                86    12728000   5982000
# 252          Texas           105000                79     8295000   2986000
# 225          Idaho           100000                47     4700000   2679000
# 258      Wisconsin            84000                90     7560000   4385000
# 234       Michigan            72000                75     5400000   2970000
# 243        NewYork            58000                80     4640000   2274000
# 223        Georgia            55000                57     3135000    376000
# 219       Arkansas            55000                93     5115000   3529000
# 256     Washington            52000                54     2808000   1151000
# 239       Nebraska            50000                87     4350000   2610000
# 248         Oregon            48000                51     2448000   1665000
# 231      Louisiana            43000                94     4042000   1334000
# 218        Arizona            40000                59     2360000   1322000
# 259        Wyoming            39000                93     3627000    798000
# 228           Iowa            30000                67     2010000   1206000
# 221       Colorado            29000                60     1740000    957000
# 253           Utah            24000                41      984000    462000
# 237       Missouri            23000                75     1725000    362000
# 249   Pennsylvania            22000                45      990000    554000
# 246           Ohio            18000                65     1170000    585000
# 236    Mississippi            17000                72     1224000    649000
# 217        Alabama            16000                78     1248000    187000
# 229         Kansas            15000                68     1020000    520000
# 242      NewMexico            15000                64      960000    739000
# 244  NorthCarolina            11000                49      539000    243000
# 232          Maine            11000                21      231000    143000
# 241      NewJersey            11000                35      385000    200000
# 240         Nevada            10000                35      350000     95000
# 251      Tennessee             9000                61      549000    104000
# 226       Illinois             8000                61      488000    146000
# 227        Indiana             8000                65      520000    286000
# 224         Hawaii             7000               112      784000    125000
# 247       Oklahoma             7000                35      245000     64000
# 254        Vermont             7000                59      413000    211000
# 255       Virginia             7000                42      294000    103000
# 257   WestVirginia             7000                54      378000    234000
# 233       Maryland             6000                46      276000     52000
# 230       Kentucky             3000                48      144000     40000
#
#      average_price  value_of_production  year
# 220           58.0             17864000  2000
# 245           56.0             18676000  2000
# 250           57.0             16208000  2000
# 222           54.0             13154000  2000
# 235           57.0              7695000  2000
# 238           59.0              7510000  2000
# 252           57.0              4728000  2000
# 225           52.0              2444000  2000
# 258           68.0              5141000  2000
# 234           60.0              3240000  2000
# 243           55.0              2552000  2000
# 223           63.0              1975000  2000
# 219           57.0              2916000  2000
# 256           58.0              1629000  2000
# 239           59.0              2567000  2000
# 248           66.0              1616000  2000
# 231           52.0              2102000  2000
# 218           73.0              1723000  2000
# 259           59.0              2140000  2000
# 228           67.0              1347000  2000
# 221           62.0              1079000  2000
# 253           60.0               590000  2000
# 237           60.0              1035000  2000
# 249           76.0               752000  2000
# 246           79.0               924000  2000
# 236           69.0               845000  2000
# 217           59.0               736000  2000
# 229           91.0               928000  2000
# 242           72.0               691000  2000
# 244          143.0               771000  2000
# 232           75.0               173000  2000
# 241           61.0               235000  2000
# 240          145.0               508000  2000
# 251          143.0               785000  2000
# 226          117.0               571000  2000
# 227          103.0               536000  2000
# 224           81.0               635000  2000
# 247          126.0               309000  2000
# 254           68.0               281000  2000
# 255          150.0               441000  2000
# 257          122.0               461000  2000
# 233          114.0               315000  2000
# 230          135.0               194000  2000

# %% [markdown]
# # Conclusion
#
# California is the state with highest no of colonies in year 2000
