# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Statistic
#
#
#
# # 1) Descriptive Statistics
#
# It will have your core mathematical functions for data analysis
#
#
#
# 1-> Measure of Central Tendancy ( To find the centre of your data )
#
# Mean
#
# Mode
#
# Median
#
#
# 2-> Measure of Dispersion  ( To calculate the spread of data )
#
# Range
#
# Variance
#
# Standards deviation
#
# Percentage
#
# Percentile
#
# Quartile
#
# Outliers
#
# Correlation
#
# Covariance
#
# Skewness
#
# Kurtosis
#
# Normal distribution
#
#
#
#
# # 2) Inferential statistic
#
# It will have hypothesis and all
#
# Null Hypothesis
#
# Alternate Hypothesis
#
#
# ----------------------------------------------------------------------
#
# # Probability
#
# Marginal Probability
#
# Conditional Probability

# %%
# Handson

# %% [markdown]
# # Measure of Central Tendancy ( To find the centre of your data )

# %% [markdown]
# # Mean
#
# Average of your data

# %%
'''
data = [500,750,1200,2500,1150,5600,4120]
Average / Mean = (Sum of all values) / Total no of value
Average / Mean = 15820 / 7
Average / Mean = 2260
'''
# Out:
# '\ndata = [500,750,1200,2500,1150,5600,4120]\nAverage / Mean = (Sum of all values) / Total no of value\nAverage / Mean = 15820 / 7\nAverage / Mean = 2260\n'

# %%
import numpy as np
data = [500,750,1200,2500,1150,5600,4120]
ans = np.mean(data)
print(ans)
# Out:
# 2260.0

# %%
import statistics as stats
data = [500,750,1200,2500,1150,5600,4120]
ans = stats.mean(data)
print(ans)
# Out:
# 2260

# %% [markdown]
# # Median
#
# Middle value of your data

# %%
'''
data = [ 5,11,12,2,3,6,7,9 ]

First sort your data ( Ascending or Descending )
Second check do you have EVEN no of values or ODD no of values in your data

We have 8 value so we will apply the EVEN formula

data = [ 5,11,12,2,3,6,7,9 ]
sorted_data = [ 2,3,5,6,7,9,11,12]
Median = Sum of middle 2 values / 2
Median = 6+7 /2
Median = 13/2
Median = 6.5
'''
# Out:
# '\ndata = [ 5,11,12,2,3,6,7,9 ]\n\nFirst sort your data ( Ascending or Descending )\nSecond check do you have EVEN no of values or ODD no of values in your data\n\nWe have 8 value so we will apply the EVEN formula\n\ndata = [ 5,11,12,2,3,6,7,9 ]\nsorted_data = [ 2,3,5,6,7,9,11,12]\nMedian = Sum of middle 2 values / 2\nMedian = 6+7 /2\nMedian = 13/2\nMedian = 6.5\n'

# %%
data = [ 5,11,12,2,3,6,7,9 ]
ans = np.median(data)
print(ans)
# Out:
# 6.5

# %%
data = [ 5,11,12,2,3,6,7,9 ]
ans = stats.median(data)
print(ans)
# Out:
# 6.5

# %%
'''
data = [ 5,2,7,8,5,9,1,3,5 ]

First sort your data ( Ascending or Descending )
Second check do you have EVEN no of values or ODD no of values in your data

We have 9 value so we will apply the ODD formula

data = [ 5,2,7,8,5,9,1,3,5 ]
sorted_data = [ 1,2,3,5,5,5,7,8,9]

Median = n+1 / 2 position
Median = 10/2 position
Median = 5th position
Median = 5
'''
# Out:
# '\ndata = [ 5,2,7,8,5,9,1,3,5 ]\n\nFirst sort your data ( Ascending or Descending )\nSecond check do you have EVEN no of values or ODD no of values in your data\n\nWe have 9 value so we will apply the ODD formula\n\ndata = [ 5,2,7,8,5,9,1,3,5 ]\nsorted_data = [ 1,2,3,5,5,5,7,8,9]\n\nMedian = n+1 / 2 position\nMedian = 10/2 position\nMedian = 5th position\nMedian = 5\n'

# %%
data = [ 5,2,7,8,5,9,1,3,5 ]
ans = np.median(data)
print(ans)
# Out:
# 5.0

# %%
data = [ 5,2,7,8,5,9,1,3,5 ]
ans = stats.median(data)
print(ans)
# Out:
# 5

# %% [markdown]
# # Mode
#
# Most common value / Most frequent value / Most repeated value / The value having highest frequency

# %%
'''
data = [ 1,4,11,12,23,23,56,23,78,1,1,4,11,23,11,19]

We need to calculate the frequency of each value
1= 3 times
4= 2 times
11= 3 times
12= 1 times
19= 1 times
23= 4 times
56= 1 times
78= 1 times

so 23 is being repeated most no of times so 23 is the mode of this data

'''
# Out:
# '\ndata = [ 1,4,11,12,23,23,56,23,78,1,1,4,11,23,11,19]\n\nWe need to calculate the frequency of each value\n1= 3 times\n4= 2 times\n11= 3 times\n12= 1 times\n19= 1 times\n23= 4 times\n56= 1 times\n78= 1 times\n\nso 23 is being repeated most no of times so 23 is the mode of this data\n\n'

# %%
data = [ 1,4,11,12,23,23,56,23,78,1,1,4,11,23,11,19]
ans = stats.mode(data)    # Numpy dont have mode only stats library you can use
print(ans)
# Out:
# 23

# %%
'''
data = [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]

We need to calculate the frequency of each value
1= 3 times
4= 2 times
11= 4 times
12= 1 times
19= 1 times
23= 4 times
56= 1 times
78= 1 times

NOW MORE THAN 1 VALUE IS BEING REPATED SAME NO OF TIME / MORE THEN 1 VALUE IS HAVING SAME HIGHEST FREQUENCY

Are we going to have multimode ( Means 11 and 23 both are going to be the mode )   ?
Are we going to have only 1 mode by using some logic or approach   ?


1st group of Mathemticians - We can have multimode

2nd group of Mathemticians - We will only have 1 mode so if more than 1 value is having same highest frequency then the value that will come first
                             in my data is going to be the mode so if this is the data [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]
                             11 is coming 4 times
                             23 is also coming 4 times
                             so 11 is going to be the Mode
'''
# Out:
# '\ndata = [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]\n\nWe need to calculate the frequency of each value\n1= 3 times\n4= 2 times\n11= 4 times\n12= 1 times\n19= 1 times\n23= 4 times\n56= 1 times\n78= 1 times\n\nNOW MORE THAN 1 VALUE IS BEING REPATED SAME NO OF TIME / MORE THEN 1 VALUE IS HAVING SAME HIGHEST FREQUENCY\n\nAre we going to have multimode ( Means 11 and 23 both are going to be the mode )   ?\nAre we going to have only 1 mode by using some logic or approach   ?\n\n\n1st group of Mathemticians - We can have multimode\n\n2nd group of Mathemticians - We will only have 1 mode so if more than 1 value is having same highest frequency then the value that will come first\n                             in my data is going to be the mode so if this is the data [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]\n                             11 is coming 4 times\n                             23 is also coming 4 times\n                             so 11 is going to be the Mode\n'

# %%
data = [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]
ans = stats.mode(data)
print(ans)
# Out:
# 11

# %%
data = [ 1,4,23,12,11,11,23,56,23,78,1,1,4,11,23,11,19]
ans = stats.mode(data)
print(ans)
# Out:
# 23

# %%
data = [11,10,1,2,3,4,5,6,7,8,9]
ans = stats.mode(data)
print(ans)
# Out:
# 11

# %%
# How to find multimode
data = [ 1,4,11,12,11,23,23,56,23,78,1,1,4,11,23,11,19]
ans = stats.multimode(data)
print(ans)
# Out:
# [11, 23]

# %%
# FAQ - How to sort the data in python

# Ascending order
data = [4,8,87,567,986,26,99,76,567,999 , 56.09 , 4.5]
data.sort()
print(data)
# Out:
# [4, 4.5, 8, 26, 56.09, 76, 87, 99, 567, 567, 986, 999]

# %%
# Descending order
data = [4,8,87,567,986,26,99,76,567,999 , 56.09 , 4.5]
data.sort(reverse=True)
print(data)
# Out:
# [999, 986, 567, 567, 99, 87, 76, 56.09, 26, 8, 4.5, 4]

# %% [markdown]
# # Measure of Dispersion
#
# The operation that will give us the idea about the spread of our data

# %% [markdown]
# # Range
#
#
# Just the difference between the highest values and lowest value of your data

# %%
'''
salary_data = [ 25000 , 47000 , 84000 , 251000 , 421500 , 30000 , 10000]

highest_value = 421500
lowest_value =  10000

Range = highest_value - lowest_value
Range = 421500 - 10000
Range = 411500
'''
salary_data = [ 25000 , 47000 , 84000 , 251000 , 421500 , 30000 , 10000]
ans = np.ptp(salary_data)    # Use .ptp for finding range
print(ans)
# Out:
# 411500

# %% [markdown]
# # Variance
#
# **It quantifies the spread of data around the mean**
#
#
# In simple words variance will help me to get the idea that values in my data is close to each other or values in my data are far away from each other

# %%
data_1 = [1,5,12,7,3,19,18,11,16,6,0.5,10.5,17.2]    #1st type of data in which values are close to each other      - Data with low variance
data_2 = [1 , 100 , 550.5 , 158 , 333 , 97539 , 45]  #2nd type of data in which values are far away from each other - Data with high variance

print("Variance of data 1 is :", np.var(data_1))
print("Variance of data 2 is :", np.var(data_2))
# Out:
# Variance of data 1 is : 39.01763313609468
# Variance of data 2 is : 1160270007.1326532

# %%
'''
data_1 = [25,30,35,40,45,55,50,60,65,70]

variance = Sum of squared difference between each data point and mean / Total no of data points - 1
Mean = 47.5

variance = [ (25-47.5)^2 +(30-47.5)^2 +(35-47.5)^2 +(40-47.5)^2 +(45-47.5)^2 +(55-47.5)^2 +(50-47.5)^2 +(60-47.5)^2 +(65-47.5)^2 +(70-47.5)^2 ] / 9
variance = [ -22.5^2 + -17.5^2 +  -12.5^2 + -7.5^2 + -2.5^2 + 7.5^2 + 2.5^2 + 12.5^2 + 17.5^2 + 22.5^2 ] / 9
variance = 229.16

'''
# Numpy will calculate your Population variance
# variance = Sum of squared difference between each data point and mean / Total no of data points
data_var = [25,30,35,40,45,55,50,60,65,70]
print("Variance of this data by using numpy is :", np.var(data_var))

# Stats will calculate your Sample variance
# variance = Sum of squared difference between each data point and mean / Total no of data points - 1
data_var = [25,30,35,40,45,55,50,60,65,70]
print("Variance of this data  by using stats is :", stats.variance(data_var))
# Out:
# Variance of this data by using numpy is : 206.25
# Variance of this data  by using stats is : 229.16666666666666

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Population - Full data
# Sample - A part of that full data

# %% [markdown]
# # Standard Deviation
#
# It indicates how much a individual data point deviates from mean
#
# In simple word = it means on a average how much these individual individual data points are far aways from their mean value
#
#
# Standard deviation = Square root of Variance

# %%
data_var = [25,30,35,40,45,55,50,60,65,70]
print("Variance of this data  by using stats is :", stats.variance(data_var))
print("Standard deviation of this data by using stats is :" , np.sqrt(stats.variance(data_var)))
print("Standard deviation of this data by using stats is :" , stats.stdev(data_var))
# Out:
# Variance of this data  by using stats is : 229.16666666666666
# Standard deviation of this data by using stats is : 15.138251770487457
# Standard deviation of this data by using stats is : 15.138251770487459

# %% [markdown]
# # Percentage
#
# **A percentage is an absolute measure of a value out of 100**

# %%
'''
A school child - Rohan got 58 percent marks
This means Rohan got 58/100
'''
# Out:
# '\nA school child - Rohan got 58 percent marks\nThis means Rohan got 58/100\n'

# %% [markdown]
# # Percentile
#
#
# **while a percentile is a relative rank comparing your score against a larger group.**

# %%
'''
A Jee Mains exam was there - Rohan got 99 percentile
So this means whatever marks Rohan got ( let it be 300/320 or 250/320 or any marks ) those marks are more than 99% of all students who attended the exam and got the marks
'''

data = [ 1,5,2,10,45,67,33,29,19,61,54,45,12,9]
# Calcuate 90 percentile of this data
print("90 percentile of this data is :",np.percentile(data , 90))


'''
data = [ 1,5,2,10,45,67,33,29,19,61,54,45,12,9]
data = [1,2,5,9,10,12,19,29,33,45,45,54,61,67]   # same data after sorting
so we got 90 percentile as 58.90
this means 90% of values in my data is less than 58.90
'''

'''
Children have chocolates
data=[Priya:5 , Rahul:10 , Aman:20 , Alice:19 , Bob:25 , Chris:29]
so let say Bob got 90 percentile that means whatever chococlates bob got that no is still more the 90% of other child chococlate no
'''
# Out:
# 90 percentile of this data is : 58.900000000000006
# '\nChildren have chocolates\ndata=[Priya:5 , Rahul:10 , Aman:20 , Alice:19 , Bob:25 , Chris:29]\nso let say Bob got 90 percentile that means whatever chococlates bob got that no is still more the 90% of other child chococlate no\n'

# %% [markdown]
# # Outliers
#
# Extreme values that falls outside the normal range of our data

# %%
'''
For example = [ 1,111,10,5,30,-561 , 99,85,67,46,31,28,17,82,92 ,567,5,22 ,19,55,67,84 ,491 ]
Normal range of this data is 1 to 111

We have 3 such values here that are differing from the normal range of our data those values are -561 ,  567 , 491
These 3 values are outliers
'''
# Out:
# '\nFor example = [ 1,111,10,5,30,-561 , 99,85,67,46,31,28,17,82,92 ,567,5,22 ,19,55,67,84 ,491 ]\nNormal range of this data is 1 to 111\n\nWe have 3 such values here that are differing from the normal range of our data those values are -561 ,  567 , 491\nThese 3 values are outliers\n'

# %% [markdown]
# How to detect the outliers in our data - Box Plot

# %%
data = [ 1,111,10,5,30,-561 , 99,85,67,46,31,28,17,82,92 ,567,5,22 ,19,55,67,84 ,491 ]
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data)
plt.show()

# %%
data = [ 1,111,10,5,30 , 99,85,67,46,31,28,17,82,92,5,22 ,19,55,67,84]
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = [ 1,111,10,5,30,-561 , 99,85,67,46,31,28,17,82,92 ,567,5,22 ,19,55,67,84 ,491 ]

Q1= np.percentile(data , 25)
Q3= np.percentile(data , 75)
IQR = Q3-Q1
Lower_fence = Q1 - 1.5*IQR
Upper_fence = Q3 + 1.5*IQR

print(Lower_fence)
print(Upper_fence)

for i in data:
  if (i > Upper_fence) or (i<Lower_fence):
    data.remove(i)
print(data)
# Out:
# -81.75
# 184.25
# [1, 111, 10, 5, 30, 99, 85, 67, 46, 31, 28, 17, 82, 92, 5, 22, 19, 55, 67, 84]

# %% [markdown]
# # Quantile / Quartile

# %%
data = [1, 111, 10, 5, 30, 99, 85, 67, 46, 31, 28, 17, 82, 92, 5, 22, 19, 55, 67, 84]
print(np.percentile(data,20))
print(np.percentile(data,77))
print(np.percentile(data,99))
print(np.percentile(data,50))

Q1=np.percentile(data,25)
Q2=np.percentile(data,50)
Q3=np.percentile(data,75)
# Out:
# 15.600000000000001
# 83.26
# 108.71999999999998
# 38.5

# %% [markdown]
# FAQ - but sir even 5 cr is like 1% for Population fof india then how do we come up with whole country Statistics

# %%
population_data=[1,2,3,1,5,7,8,9,10,4,6,8,4,2,1,8,9,11,13,12,14,16,2,19,18,11,16,18,15]
# Lets calculate the variance of population data
print("Variance of population data :" ,np.var(population_data))


# Lets collect some randdom sample
sample_data=[11,10,2,19,11,3,1,5,7,16,1]
# Lets calculate the variance of sample data
print("Variance of sample data :" ,np.var(sample_data))
# Out:
# Variance of population data : 31.37217598097503
# Variance of sample data : 34.14876033057851

# %% [markdown]
# # Correlation
#
#
# **The relationship between 2 values / data / columns**
#
# For example -
#
# Temperature and Ice cream sales
#
# if temp will increase = ice cream sales will also increase
#
# if temp will decrease = ice cream sales will also decrease
#
#
# For example -
#
# Speed and time to reach the destination
#
# if speed will increase = The time taken to reach the destination will decrease
#
# if speed will decrease = The time taken to reach the destination will increase

# %% [markdown]
# **Positive correlation** = If x will increase , y will also increase  or
# if x will decrease , y will also decrease ( They are moving in same direction )
#
#
# **Negative correlation** = If x will increase , y will decrease ( They will move in opposite direction )
#
# **No correlation**- No relationship both x and y are independent to each other

# %% [markdown]
# Dataset link : https://drive.google.com/file/d/1EoKzUS1c_stK6B6NAfD52e0z--sYwgHc/view?usp=sharing

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("Housing.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_610/986335530.py in <cell line: 0>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("Housing.csv")
#       4 df
#
# ...

# %%
# As correlation we can only calculate with numerical values so lets filter out numerical data first from our data
new_data = df.select_dtypes(include="number")
new_data

# %%
new_data.corr()  # To get the correlation table

# %% [markdown]
# # Covariance
#
# It will provide the actual value like if x will increase how much y will increase or decrease

# %%
new_data.cov()  # To get the covariance table

# %% [markdown]
# # Normal distribution
#
# You data is being distributed properly means there is a proper balance between the values
#
# A normal distribued data will have same value as its Mean , Median , Mode

# %%
data = [15,16,16,17,17,17,18,18,19]
plt.hist(data,bins=5,edgecolor="black")
plt.show()

print("Mean of this data is :",np.mean(data))
print("Median of this data is :",np.median(data))
print("Mode of this data is :",stats.mode(data))
# Out:
# Mean of this data is : 17.0
# Median of this data is : 17.0
# Mode of this data is : 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Skewness
#
# it describes the shape of data in the form of Right skewed (+ve) or Left skewed (-ve)

# %%
# Right skewed data (+Ve)  - Mean the tail of data is going to be on right side
data=[10,10,10,10,10,11,11,12]
plt.hist(data,bins=3,edgecolor="black")
plt.show()

from scipy.stats import skew
print("Skewness value of this Right/Positively skewed data is :", skew(data))
# Out:
# Skewness value of this Right/Positively skewed data is : 1.0606601717798212

# %%
# Left skewed data (-Ve)  - Mean the tail of data is going to be on left side
data=[10,11,11,12,12,12,12,12]
plt.hist(data,bins=3,edgecolor="black")
plt.show()

from scipy.stats import skew
print("Skewness value of this Left/Negatively skewed data is :", skew(data))
# Out:
# Skewness value of this Left/Negatively skewed data is : -1.0606601717798212

# %% [markdown]
# # Kurtosis
#
# it describes the shape of data in the form of peakedness (+ve) or tailedness (-ve)

# %%
# Peakedness graph ( +ve Kurtosis value )
data=[10,11,11,12,12,12,12,12,12,12,12,12,12,13,13,14]
plt.hist(data,bins=3,edgecolor="black")
plt.show()

from scipy.stats import kurtosis
print("Kurtosis value of this Peaked  data is :", kurtosis(data))
# Out:
# Kurtosis value of this Peaked  data is : 1.0

# %%
# Tailedness graph ( -ve Kurtosis value )
data=[11,10,13,14,12]
plt.hist(data,bins=5,edgecolor="black")
plt.show()

from scipy.stats import kurtosis
print("Kurtosis value of this Tailed  data is :", kurtosis(data))
# Out:
# Kurtosis value of this Tailed  data is : -1.3

# %% [markdown]
# # Data types
#
#
# 1) Categorical data / Qualitative data
#
# This type of data will represent categories or qualities and doesn't involve any numbers in a meaningful way
#
# example
#
# ["Small-1","Medium-2,"Large-3"]
#
# ["Boy","Girl"]
#
# ["Yes","No","Maybe"]
#
# ["Good","Bad"]
#
# **Types of Categorical data / Qualitative data**
#
# -> Nominal data
#
# -> Ordinal data
#
# -----------------------------------------------------------------------
#
#
# 2) Numerical data / Quantitative data
#
# This type of data will represent numbers in a meaningful way
#
# example
#
# [1,2,3,4,5]
#
# [123124,6356754,3676547478]
#
# [23.4 , 67.6 , 888.77 ]
#
#
# **Types of Numerical data / Quantitative data**
#
#
# -> Discrete data
#
# -> Continuous data

# %% [markdown]
# # Probability basics
